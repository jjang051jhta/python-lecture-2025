# %% [markdown]
# ### 1) CSV 파일을 pandas DataFrame으로 불러오세요.

# %%
import pandas as pd
#df = pd.read_csv("./korean_netflix.csv", sep=",")
df = pd.read_csv("./korean_netflix.csv")
print(df)
# Out:
#    show_id     type      title director cast   country  release_year  \
# 0      201  TV Show         킹덤      김성훈  주지훈      대한민국        2019.0
# 1      202    Movie        기생충      봉준호  송강호      대한민국        2019.0
# 2      203    Movie        부산행      NaN   공유      대한민국        2016.0
# 3      204  TV Show    미스터 션샤인      이응복  NaN      대한민국        2018.0
# 4      205    Movie       올드보이      박찬욱  최민식       NaN        2003.0
# 5      206  TV Show  응답하라 1988      NaN  박보검      대한민국        2015.0
# 6      207    Movie         명량      김한민  NaN      대한민국        2014.0
# 7      208    Movie         암살      최동훈  전지현  대한민국, 중국        2015.0
# 8      209  TV Show       스위트홈      NaN   송강       NaN        2020.0
# 9      210    Movie       국제시장      NaN  황정민      대한민국           NaN
#
#    duration  listed_in
# 0     720.0     TV 스릴러
# 1     132.0        NaN
# 2     118.0  액션 & 어드벤처
# 3    2400.0     TV 드라마
# 4     120.0        스릴러
# 5       NaN     TV 드라마
# 6     128.0        NaN
# 7     139.0         액션
# 8     800.0     TV 판타지
# 9     126.0        드라마

# %% [markdown]
# ### 2)데이터의 행(row) 수와 열(column) 수를 출력하세요.

# %%
import pandas as pd
df = pd.read_csv("./korean_netflix.csv")
print(df.shape)
# Out:
# (10, 9)

# %% [markdown]
# ### 3)모든 컬럼 이름을 리스트 형태로 출력하세요.

# %%
import pandas as pd
df = pd.read_csv("./korean_netflix.csv")
print(list(df.columns))
# Out:
# ['show_id', 'type', 'title', 'director', 'cast', 'country', 'release_year', 'duration', 'listed_in']

# %% [markdown]
# ### 4)데이터의 앞에서 5개 행만 출력하세요.

# %%
import pandas as pd
df = pd.read_csv("./korean_netflix.csv")
print(df.head())
# Out:
#    show_id     type    title director cast country  release_year  duration  \
# 0      201  TV Show       킹덤      김성훈  주지훈    대한민국        2019.0     720.0
# 1      202    Movie      기생충      봉준호  송강호    대한민국        2019.0     132.0
# 2      203    Movie      부산행      NaN   공유    대한민국        2016.0     118.0
# 3      204  TV Show  미스터 션샤인      이응복  NaN    대한민국        2018.0    2400.0
# 4      205    Movie     올드보이      박찬욱  최민식     NaN        2003.0     120.0
#
#    listed_in
# 0     TV 스릴러
# 1        NaN
# 2  액션 & 어드벤처
# 3     TV 드라마
# 4        스릴러

# %% [markdown]
# ### 5)title, type, release_year 컬럼만 선택하여 출력하세요.

# %%
import pandas as pd
df = pd.read_csv("./korean_netflix.csv")
print(df[["title","type","release_year"]])
print(df.loc[:,["title","type","release_year"]])
# Out:
#        title     type  release_year
# 0         킹덤  TV Show        2019.0
# 1        기생충    Movie        2019.0
# 2        부산행    Movie        2016.0
# 3    미스터 션샤인  TV Show        2018.0
# 4       올드보이    Movie        2003.0
# 5  응답하라 1988  TV Show        2015.0
# 6         명량    Movie        2014.0
# 7         암살    Movie        2015.0
# 8       스위트홈  TV Show        2020.0
# 9       국제시장    Movie           NaN
#        title     type  release_year
# 0         킹덤  TV Show        2019.0
# 1        기생충    Movie        2019.0
# 2        부산행    Movie        2016.0
# 3    미스터 션샤인  TV Show        2018.0
# 4       올드보이    Movie        2003.0
# 5  응답하라 1988  TV Show        2015.0
# 6         명량    Movie        2014.0
# 7         암살    Movie        2015.0
# 8       스위트홈  TV Show        2020.0
# 9       국제시장    Movie           NaN

# %% [markdown]
# ### 6)title, director, release_year 컬럼을 선택한 뒤 앞에서 5개 행을 왼쪽 정렬로 출력하세요.

# %%
print(df[["title","director","release_year"]].head().to_string(justify="left"))
# Out:
#   title    director  release_year
# 0       킹덤  김성훈      2019.0
# 1      기생충  봉준호      2019.0
# 2      부산행  NaN      2016.0
# 3  미스터 션샤인  이응복      2018.0
# 4     올드보이  박찬욱      2003.0

# %% [markdown]
# ### 7)type이 "Movie"인 데이터만 추출하여 출력하세요.

# %%
print(df[df["type"]=="Movie"])
# Out:
#    show_id   type title director cast   country  release_year  duration  \
# 1      202  Movie   기생충      봉준호  송강호      대한민국        2019.0     132.0
# 2      203  Movie   부산행      NaN   공유      대한민국        2016.0     118.0
# 4      205  Movie  올드보이      박찬욱  최민식       NaN        2003.0     120.0
# 6      207  Movie    명량      김한민  NaN      대한민국        2014.0     128.0
# 7      208  Movie    암살      최동훈  전지현  대한민국, 중국        2015.0     139.0
# 9      210  Movie  국제시장      NaN  황정민      대한민국           NaN     126.0
#
#    listed_in
# 1        NaN
# 2  액션 & 어드벤처
# 4        스릴러
# 6        NaN
# 7         액션
# 9        드라마
