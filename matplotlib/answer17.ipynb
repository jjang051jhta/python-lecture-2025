# %% [markdown]
# ### 1) 승선 항구(`Embarked`)별 **전체 승객 수**를 계산하여 세로 막대그래프로 시각화하시오.
#
# 조건
#
# - x축: Embarked (C, Q, S)
# - y축: 승객 수
# - 결측치 제거
# - 막대 위에 값 표시

# %%
import pandas as pd
import matplotlib.pyplot as plt

plt.rcParams["font.family"] = "Malgun Gothic"   # 윈도우 기본 한글 폰트
plt.rcParams["axes.unicode_minus"] = False  
titanic = pd.read_csv("./titanic.csv")
#print(titanic)
embarked_count = titanic["Embarked"].dropna().value_counts()
print(embarked_count.index)
print(embarked_count.values)
plt.bar(embarked_count.index,embarked_count.values, 
        color=["#ebb400","#00ade2","#02f00e"], 
        edgecolor="#000000")
plt.ylim(0,embarked_count.max()*1.15)
for i,value in enumerate(embarked_count.values):
  plt.text(i,value+5, value,ha="center", va="bottom")
plt.title("항구별 승선인원")
plt.xlabel("항구이름")
plt.ylabel("인원수")
# Out:
# Index(['S', 'C', 'Q'], dtype='object', name='Embarked')
# [644 168  77]
# Text(0, 0.5, '인원수')

# %% [markdown]
# ### 2)연령(`Age`)을 기준으로 **연령대별 평균 생존 비율**을 계산하여 선형 그래프로 시각화하시오.
#
# 조건
#
# - 연령 구간 예: 0–9, 10–19, 20–29 …
# - 결측치 제거
# - marker 표시

# %%
import pandas as pd
import matplotlib.pyplot as plt

plt.rcParams["font.family"] = "Malgun Gothic"   # 윈도우 기본 한글 폰트
plt.rcParams["axes.unicode_minus"] = False  
titanic = pd.read_csv("./titanic.csv")
#print(titanic)
#print(titanic["Age"].isna().sum()) #NaN 데이터가 들어가 있는 갯수
df = titanic.dropna(subset=["Age"])  #Age에 NaN이 있으면 제거  다른 컬럼에 NaN이 있어도 제거하지 마라
#print(df["Age"].isna().sum())
df["AgeGroup"] = pd.cut(df["Age"], bins=range(0,81,10))
age_survive = df.groupby("AgeGroup")["Survived"].mean()
plt.plot(age_survive.index.astype(str),age_survive.values, marker="o")

#print(df)
# Out:
# C:\Users\201-08\AppData\Local\Temp\ipykernel_27188\3196840379.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["AgeGroup"] = pd.cut(df["Age"], bins=range(0,81,10))
# C:\Users\201-08\AppData\Local\Temp\ipykernel_27188\3196840379.py:12: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   age_survive = df.groupby("AgeGroup")["Survived"].mean()
