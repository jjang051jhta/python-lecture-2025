# %%
print("hello python")
# Out:
# hello python

# %% [markdown]
# # list에 대해서 알아봅시다.
# ## 중간제목
# ### 작은 제목
#
# 1. 프론트엔드
#     - HTML
#     - CSS
#     - JS
# 2. 백엔드
#     - PYTHON
#     - JAVA
#     - Spring
#
# [네이버] (http://www.naver.com)
#
# ```python
# print(type(False))
# name = input("이름을 입력하세요 : ")
# age = int(input("나이를 입력하세요 : "))
# print(f"{name} / {age + 10}")
# ```
#
# ```java
# System.out.print()
# ```
#
# ```html
# <h1>hello pytho</h1>
# ```
# ![대체 텍스트](../pumpkin.png)
# ![전지현](https://thumbnews.nateimg.co.kr/view610///news.nateimg.co.kr/orgImg/tt/2024/03/08/news-p.v1.20240308.fcd68ba9eb7c492885bdf119fe644504_P1.jpg)
#
# <img src="https://thumbnews.nateimg.co.kr/view610///news.nateimg.co.kr/orgImg/tt/2024/03/08/news-p.v1.20240308.fcd68ba9eb7c492885bdf119fe644504_P1.jpg" width="200">
#
# <h1>hello</h1>

# %%
odd = [1,3,5,7,9]
animals = ["rabbit","lion","bear"]
blankList = list()
print(odd)
print(odd[0])
# Out:
# [1, 3, 5, 7, 9]
# 1
