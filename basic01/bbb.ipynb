# %%
tuple01 = (1,2,3)
tuple02 = (1,)
print(type(tuple02))
print(tuple02)
# Out:
# <class 'tuple'>
# (1,)

# %% [markdown]
# 1. 프론트엔드
#    - HTML
#    - CSS
#    - JavaScript
# 2. 백엔드
#    - Python
#    - Java
#    - Spring

# %% [markdown]
# # hello python

# %%
sfds

# %%
fdsfd
