# %% [markdown]
# ### 1) 오늘 날짜 폴더 자동 생성
#
# **설명:**
#
# 오늘 날짜를 기준으로 `logs/YYYY/MM/DD` 형식의 폴더를 자동으로 생성하는 코드를 작성하시오.
#
# 예: 2025-12-11 → `logs/2025/12/11` 폴더 생성

# %%
from datetime import date
import os
from pathlib import Path

today = date(2025,3,3)
date_path = today.strftime("%Y/%m/%d")
print(today)
#folder = os.path.join("logs",str(today.year),str(today.month),str(today.day))
folder = os.path.join("logs",date_path)
os.makedirs(folder,exist_ok=True)
# Out:
# 2025-03-03

# %%
from datetime import date
import os
from pathlib import Path

today = date(2025,3,3)
date_path = today.strftime("%Y/%m/%d")
folder = Path("logs") / date_path
folder.mkdir(parents=True,exist_ok=True)
print(folder)
# Out:
# logs\2025\03\03
